# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/THIRU/Documents/DATA SET/TATASTEEL.csv')

# %%
df.head()
# Out:
#          Date Symbol Series  Prev Close    Open   High     Low    Last  \
# 0  2000-01-03  TISCO     EQ      142.35  148.00  153.2  146.10  152.50
# 1  2000-01-04  TISCO     EQ      152.45  150.10  153.0  143.05  151.95
# 2  2000-01-05  TISCO     EQ      150.80  144.60  162.9  144.60  158.00
# 3  2000-01-06  TISCO     EQ      156.55  158.95  169.1  158.95  169.00
# 4  2000-01-07  TISCO     EQ      168.25  173.40  179.0  166.30  170.55
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  152.45  150.92  2003185  3.023164e+13     NaN                 NaN
# 1  150.80  151.03  1555136  2.348785e+13     NaN                 NaN
# 2  156.55  156.85  3840284  6.023364e+13     NaN                 NaN
# 3  168.25  167.61  2560449  4.291530e+13     NaN                 NaN
# 4  171.95  173.89  3641691  6.332459e+13     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %%
df.shape
# Out:
# (5306, 15)

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
df.drop(columns = ['Trades','Symbol','Series'],axis = 1,inplace=True)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4792, 12)

# %%
df.describe().transpose()
# Out:
#                      count          mean           std           min  \
# Prev Close          4792.0  4.334549e+02  1.694492e+02  8.590000e+01
# Open                4792.0  4.344013e+02  1.699058e+02  8.690000e+01
# High                4792.0  4.418076e+02  1.729222e+02  8.805000e+01
# Low                 4792.0  4.261348e+02  1.664824e+02  8.550000e+01
# Last                4792.0  4.335749e+02  1.696196e+02  8.600000e+01
# Close               4792.0  4.336707e+02  1.696539e+02  8.590000e+01
# VWAP                4792.0  4.341782e+02  1.697897e+02  8.707000e+01
# Volume              4792.0  6.635167e+06  5.379313e+06  6.605100e+04
# Turnover            4792.0  2.924496e+14  3.057102e+14  1.480944e+12
# Deliverable Volume  4792.0  1.550750e+06  1.215813e+06  2.415800e+04
# %Deliverble         4792.0  2.609513e-01  1.079025e-01  4.510000e-02
#
#                              25%           50%           75%           max
# ...

# %%
df.corr().Close.sort_values(ascending=False)
# Out:
# C:\Users\THIRU\AppData\Local\Temp\ipykernel_37748\2917633470.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().Close.sort_values(ascending=False)
# Close                 1.000000
# Last                  0.999955
# VWAP                  0.999571
# Low                   0.998779
# High                  0.998711
# Open                  0.997461
# Prev Close            0.997385
# Turnover              0.359466
# Deliverable Volume    0.106257
# %Deliverble           0.065318
# Volume                0.050441
# Name: Close, dtype: float64

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# C:\Users\THIRU\AppData\Local\Temp\ipykernel_37748\2221401063.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)
# <Axes: >

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'], marker='o', linestyle='-')
plt.title('Stock Market Performance')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
y=df['Close']

# %%
X=df.drop('Close',axis=1)

# %%
X['Date'] = X['Date'].apply(lambda x: x.timestamp())

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.head()
# Out:
#               Date  Prev Close    Open    High     Low    Last    VWAP  \
# 707   1.035936e+09       118.1  118.95  119.85  116.15  116.95  117.99
# 838   1.052784e+09       133.8  134.00  135.00  133.50  135.00  134.49
# 3354  1.370477e+09       299.1  297.00  297.00  293.25  295.10  295.21
# 3454  1.383178e+09       326.6  325.60  338.30  324.15  337.05  331.82
# 3479  1.386288e+09       421.4  421.00  424.00  418.00  423.15  420.93
#
#        Volume      Turnover  Deliverable Volume  %Deliverble
# 707    802502  9.468787e+12            192044.0       0.2393
# 838    892887  1.200799e+13            263907.0       0.2956
# 3354  3436273  1.014424e+14           1122294.0       0.3266
# 3454  6259016  2.076894e+14           2166867.0       0.3462
# 3479  4156106  1.749435e+14           1589802.0       0.3825

# %%
y_train.head()
# Out:
# 707     116.75
# 838     134.80
# 3354    295.30
# 3454    334.90
# 3479    422.70
# Name: Close, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 1.52182703e-10 -1.04554280e-02 -2.71454897e-02  1.07104072e-02
#   1.22669453e-02  8.20440387e-01  1.93961925e-01 -1.47386316e-08
#   3.86618568e-16 -3.83586474e-09 -1.86767000e-01]

# %%
c=lm.intercept_
c
# Out:
# -0.08413619033183295

# %%
#y=mX+c

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.9059138488808768
# MSE: 1.9397856396487685
# RMSE: 1.3927618747110966

# %%
metrics.explained_variance_score(y_test, predictions)
# Out:
# 0.9999342398271462
